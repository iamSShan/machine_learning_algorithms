# %%
import pandas as pd

data = [["Shantanu Sharma"], ["Peter Parker"]]
df = pd.DataFrame(data, columns=["Name"])
df
# Out:
#               Name
# 0  Shantanu Sharma
# 1     Peter Parker

# %%
def split(name):
    return name.split(" ")


df[["FirstName", "LastName"]] = df["Name"].apply(split)
# df["LastName"] = df["Name"].apply(split)[1]
# new = df["Name"].str.split(" ", )
# df["firstName"] = new[0]
# df["lastName"] = new[1]

# %% [markdown]
# y = mx+c
# yhat = y
# // Reduce Cost function
# J(01) = { - log(yhat; y =1 }
#         { -log(1-yhat; y =0 }
#
# Cancer - 1 NC- 0
# Nc-1 C-0
#
# Accuaracy  = Correct / All points
#
# recall = TP/(TP + FN)
# precision = TP/(TP+FP)
#
# TP:
# 1 -> 1
# FN:
# 0 -> 1
# 1- SSres/SStot
#
# f1
#
# 1.3
# 2.3
# 3
# 4
# 5
# 6
#
#
# Sigmoid Activation
#
# -1 to 1
#
#
# Sigmoid
#
# -ve
#
# Inbalance Data
# - IndusInd
# -
#
#
# 6-12 hours
# 8 hours
# 4 hours
#
# Caching
# Feature Importance
#
# 1500 features
# 500 features
# 0.0
#
#
# - u
# - MALE, FEMALE, UNKNOWN
#
# Feature Selection
#
# 0.5
#
# FP -> Increase 0.8
#
# FN ->
#
#
# Information Gain
#
#
#
# - Domain Know
# - Availability: Logistic Re, SVM, KNN, DT, RF, XGBoost
# - Random
#
#
# - User can book for future 7 days
# - prediction 7 days
#
#
#
#
#
# Impact of 1 day: 100 50  // 2nd day
#
# 2nd day  100 40
# 3rd day 100 30
#
# 7th day
#
# Working Fine
#
#
#
#
# O(n) * O(m)
#
# GCP
#
#
#
# ML
