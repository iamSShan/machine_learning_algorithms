# %% [markdown]
# ## Hypothesis Testing
# * We evaluate two mutual exclusive statement on a population using sample data. Then we conclude whether a population is true for a particular statement or not.
# * We can also evaluate 3-4 mutual exclusive statement too, for that we use ANOVA Test.
# * The process of hypothesis testing is to draw inferences or some conclusion about the overall population or data by conducting some statistical tests on a sample.
#
# **Steps of hypothesis Testing:**
# 1. Make an inital assumption (H0). **(** *H0 is called as null hypothesis. Opposite of H0 is called alternate hypothesis(H1)* **)**.
#
#     ### Null hypothesis:
#     * The null hypothesis states that there is no relationship between two population parameters, i.e., an independent variable and a dependent variable. If the hypothesis shows a relationship between the two parameters, the outcome could be due to an experimental or sampling error.
#     * The null hypothesis states that there is no relationship between the two variables being studied (one variable does not affect the other). It states the results are due to chance and are not significant in terms of supporting the idea being investigated. Thus, the null hypothesis assumes that whatever you are trying to prove did not happen.
#
#    ### Alternative hypothesis:
#     * The alternative hypothesis is the one you would believe if the null hypothesis is concluded to be untrue.
#
#     * The alternative hypothesis states that the independent variable did affect the dependent variable, and the results are significant in terms of supporting the theory being investigated (i.e. not due to chance).
#
#
#
# 2. Collect Data, also called evidences.
# 3. Gather the evidences and try to analyze whether to accept or reject a hypothesis.
#
# ![H0-H1.png](attachment:H0-H1.png)
#
#
# - If our assumption(null hypothesis) got rejected due to lack of evidence and alternate hypothesis got selected and afterwards null hypothesis case was actually true, this comes under Type-I Error.
# - If our assumption(null hypothesis) got accepted due to lack of evidence, afterwards we got to know that null hypothesis case was actually false, this comes under Type-II Error.
#
# * **Example-1**: Suppose a pizza place claims their delivery times are 30 minutes or less on average but you think it’s more than that. So you conduct a hypothesis test and randomly sample some delivery times to test the claim:
#
#         Null hypothesis(H0) — The mean delivery time is 30 minutes or less
#         Alternative hypothesis(H1) — The mean delivery time is greater than 30 minutes
#     The goal here is to determine which claim — the null or alternative — is better supported by the evidence found from our sample data.
#
# * **Example-2**: We are tossing a fair coin 100 times, now based on fair nature at least 50 times heads should come
#         Null hypothesis(H0) — Coin is fair
#         Alternative hypothesis(H1) — Coin is not fair
#
# ## Normal Distribution:
# * Normal distribution is a probability density function used to see the data distribution.
#
# * The normal distribution has two parameters — the mean (μ) and standard deviation, also called sigma (σ).
#
# * The mean is the central tendency of the distribution. It defines the location of the peak for normal distributions. The standard deviation is a measure of variability. It determines how far away from the mean the values tend to fall.
#
# * The normal distribution is commonly associated with the 68-95-99.7 rule(image above).
#
#         68% of the data is within 1 standard deviation (σ) of the mean (μ)
#         95% of the data is within 2 standard deviations (σ) of the mean (μ)
#         99.7% of the data is within 3 standard deviations (σ) of the mean (μ)
#
# ![normal_dist.png](attachment:normal_dist.png)
#
# ### Critical value (⍺):
# The critical values of a statistical test are the boundaries of the acceptance region of the test.
#
#
# ### P-value:
# * A p-value, or probability value, is a number describing how likely it is that your data would have occurred by random chance (i.e. that the null hypothesis is true).
# * The level of statistical significance is often expressed as a p-value between 0 and 1. The smaller the p-value, the stronger the evidence that you should reject the null hypothesis.
#
# * We can think in terms of space bar of our keyboard, most of the time we click in middle of the space bar, and less times on the sides. If we represent this thing as above bell curve, we can say most of the data points(space bar press) will be towards centre and on sides it will be low. This type of experiment is a two tailed test, as it provides two different region at the ends of bell curve.
# * Let's say if for a data point p=0.01 then it means if we repeat this experiment 100 times then number of times we will be touching that particular area(in which point is) will be 1. If for another data point P=0.7 then it means if repeat this experiment 100 times then number of times we will be touching that particular area(in which point is) will be 70 times.
# * Therefore, we can say P-value is the prbability for the null hypothesis to be true.
#
# * Now if we consider above fair coin toss example, and we perform some kind of experiment, we know mean value is 50
# ![100timescoinflip.png](attachment:100timescoinflip.png)
#
# * Now let's say after doing some experiments, we found out that we have got heads 80 times, we can see in graph, it will lie on right hand side of mean.
# * P-value and critical value, both are always selected before starting test.
# * If we have selected P-value as 0.05 and critical value also as 0.05, so if our value doesn't lie within 95% of the data(see 2nd image) then we reject the null hypothesis, else we accept it. As in this case we have considered our p-value: 0.05, so we will reject 5% (2.5% on each side). This p-value is decided by domain expertise and based on that we check where our output is falling, if it is falling outside then null hypothesis is rejected(as we can see coin toss is not fair, it is falling far from mean).
# * Here we can say that out P-value is definitely less than 0.05 as null hypothesis is false.
# * If some day, we do another test and we got 45 heads, then in this case we can consider null hypothesis to be true as value is falling in 95% region(when p=0.05). And we can say we have a fair coin.
# * We can say that:
#     * p_value > ⍺ (Critical value): Fail to reject the null hypothesis of the statistical test.
#     * p_value ≤ ⍺ (Critical value): Reject the null hypothesis of the statistical test.
# * The critical value that most statisticians choose is ⍺ = 0.05. This 0.05 means that, if we run the experiment 100 times, 5% of the times we will be able to reject the null hypothesis and 95% we will not.
#
# * P-value is also known as significance value.
#
#
# ## Types of test:
#
# ### One sample proportion test:
# * If we considering one categorical feature.
# * Here if in above example we get p-value less than 0.05 then we will reject null hypothesis.
#
#
# ### T-test:
# * Imagine you we running an experiment where you want to compare two groups and quantify the difference between them. For example:
#     * Compare if the people of one country are taller than people of another one.
#     * Compare if the brain of a person is more activated while watching happy movies than sad movies.
#
#   This comparison can be analyzed by conducting different statistical analysis, such as t-test
#
#
# * T-test is a type of inferential statistic used to study if there is a statistical difference between two groups. Mathematically, it establishes the problem by assuming that the means of the two distributions are equal (H₀: µ₁=µ₂). If the t-test rejects the null hypothesis (H₀: µ₁=µ₂), it indicates that the groups are highly probably different.
# * This test should be implemented when the groups have 20–30 samples(not more than 30). If we want to examine more groups or larger sample sizes, there are other tests more accurate than t-tests such as z-test, chi-square test or f-test.
# * The assumptions that we have to analyze when deciding the kind of test you have to implement are:
#     * Paired or unpaired: The data of both groups come from the same participants or not.
#     * Parametric or non-parametric: The data are distributed according to some distributions or not.
#
# ![ttest.png](attachment:ttest.png)
#
# * The formula for the two-sample t-test (a.k.a. the Student’s t-test) is shown below:
# ![t-test-formula.png](attachment:t-test-formula.png)
#
#     In this formula, t is the t-value, x1 and x2 are the means of the two groups being compared, s2 is the pooled standard error of the two groups, and n1 and n2 are the number of observations in each of the group
#
# ## Notes:
# * In case of two sample test, if both feature are continuous we use correlation(Pearson correlation).
# * In case of two variables, and when we have two classes in categorical feature and we have one continuous feature and we have to compare both of these features, then we use 2 sample T-test.
# * If we have more than two classes in categorical feature and we have one continuous feature, then we use ANOVA.
# * In case of two features and both are categorical features, and we have to test whether there is impact of one feature on another, then we use Chi Square test.
# * Now when we have one continous column as independent feature and target as categorical feature, then we can use logistic regression.
#
# ![tests.png](attachment:tests.png)
#
# ### ANOVA Test:
# * An ANOVA test is a way to find out if survey or experiment results are significant. In other words, they help you to figure out if you need to reject the null hypothesis or accept the alternate hypothesis.
# * It stands for "Analysis of variance".
# * ANOVA tests if there is a difference in the mean somewhere in the model (testing if there was an overall effect), but it does not tell us where the difference is (if there is one). To find where the difference is between the groups, we have to conduct post-hoc tests.
# * Read: https://towardsdatascience.com/anova-test-with-python-cfbf4013328b
