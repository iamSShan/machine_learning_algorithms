# %% [markdown]
# ### Hypothesis Testing
#
# * A statistical hypothesis test is a method of statistical inference used to decide whether the data at hand sufficiently support a particular hypothesis. Hypothesis testing allows us to make probabilistic statements about population parameters.
# * Also, Hypothesis testing is to test some hypothesis about parent population from which the sample is drawn.
#
#
#
# * **For eg**: Let's say there is blue Lays packet, now changing blue lays color to purple will increase more sale or not. So it is handed out to 5 people, but from these 5 people we cannot conclusively say that purple lays are performing better. So from how many people we need to take feedback to conclude that purple lays is better, this is all done in hypothesis testing.
# * Hypothesis testing is the solution for knowing whether a hypothesis is correct or wrong given some data.
#
# * We evaluate two mutual exclusive statement on a population using sample data. Then we conclude whether a population is true for a particular statement or not.
# * We can also evaluate 3-4 mutual exclusive statement too, for that we use ANOVA Test.
# * The process of hypothesis testing is to draw inferences or some conclusion about the overall population or data by conducting some statistical tests on a sample.
# * There are two types of hypothesis:
#     * **Null hypothesis**: There is no significant difference between populations specified in experiments, due to any experimental or sampling error. In simple terms, population value will be same as sample. It is denoted by H₀.
#     * **Alternate hypothesis**: It is opposite of null hypothesis. It is denoted by Hₐ or H₁. Here population and sample value is not same.
#
#
# In other terms:
# * Null hypothesis (H0):
# In simple terms, the null hypothesis is a statement that assumes there is no significant
# effect or relationship between the variables being studied. It serves as the starting point
# for hypothesis testing and represents the status quo or the assumption of no effect until
# proven otherwise. The purpose of hypothesis testing is to gather evidence (data) to either
# reject or fail to reject the null hypothesis in favour of the alternative hypothesis, which
# claims there is a significant effect or relationship.
#
# * Alternative hypothesis (H1 or Ha):
# The alternative hypothesis, is a statement that contradicts the null hypothesis and claims
# there is a significant effect or relationship between the variables being studied. It
# represents the research hypothesis or the claim that the researcher wants to support
# through statistical analysis.
#
#
# * *In above lays example, null hypothesis will be that there will be no difference is blue and purple lays sale. Where alternate hypothesis will tell there is difference in sale between two lays's sale*.
#
# ### Important Points
# * How to decide what will be Null hypothesis and what will be Alternate Hypothesis(Typically the Null hypothesis says nothing new is happening)
#
# * We try to gather evidence to reject the null hypothesis.
#
# * It's important to note that failing to reject the null hypothesis doesn't necessarily mean that the null hypothesis is true; it just means that there isn't enough evidence to support the alternative hypothesis.
#
# * Hypothesis tests are similar to jury trials, in a sense. In a jury trial, H0 is similar to the not-guilty verdict, and Ha is the guilty verdict. You assume in a jury trial that the defendant isn’t guilty unless the prosecution can show beyond a reasonable doubt that he or she is guilty. If the jury says the evidence is beyond a reasonable doubt, they reject H0, not guilty, in favour of Ha , guilty.
#
# **Steps of hypothesis Testing:**
#
# We will study about two techniques:
#
# **Rejection Region Approach**:
#
# 1. Make an inital assumption (H0) and (H1). **(** *H0 is called as null hypothesis. Opposite of H0 is called alternate hypothesis(H1)* **)**.
# 2. Set up a significance level(This is the probability of rejecting the null hypothesis when it is actually true, usually set at 0.05 or 0.01). 0.05 significance level denotes that if we are performing tests 100 times and 5 times null hypothesis was true, but still we reject null hypothesis. Sigificance level is denoted by α.
# 3. Check assumptions(example distribution of data, data is categorical or numerical, single column or multiple columns are there)
# 4. Based on above assumtions we decide a test: like Z-test, Student t-test, F-test, etc.
# 5. State the relevant test statistic: like Z-score in Z-test, value of t in t-test
# 6. Conduct a test
# 7. Reject or accept the null hypothesis based on test statistic
# 8. Interpret the result
#
#
# **Note**: *The term "significance level" in statistics is used to denote the threshold at which the results of a hypothesis test are considered statistically significant. This threshold is a probability value, typically denoted by α, that defines the likelihood of rejecting the null hypothesis when it is actually true (a type I error).*
#
# ***Note: Standard deviation is a measure of dispersion or scatter in a data set relative to the data's central mean value. For example, if the IQ's of some group have a standard deviation of 10, most of the group will have an IQ within approximately 10 points of the mean.***
#
#
# **Let's take an example of Z-test**:
#
# Example 1:
#
# Suppose a company is evaluating the impact of a new training program on the productivity of
# its employees. The company has data on the average productivity of its employees before
# implementing the training program. The average productivity was 50 units per day with a
# known population standard deviation of 5 units. After implementing the training program, the
# company measures the productivity of a random sample of 30 employees. The sample has an
# average productivity of 53 units per day. The company wants to know if the new training
# program has significantly increased productivity.
#
# Answer:
#
# μ(mean) = 50
#
# σ(std dev) = 5
#
# we took a sample n = 30
#
# x̄(sample mean) = 53
#
# Now company needs to see if training program has increased productivity actually or not, we can use hypthesis testing for this
#
# Performing steps of hypothesis testing:
#
# * 1) H₀(null hypothesis) μ remains 50 after training program; Hₐ(alternate hypothesis) μ > 50 after training program
# * 2) α (significance level) = Let's take it as 0.05
# * 3) Here sample size is >=30, so according to central limit theorem, sample sizes equal to or greater than 30 are often considered sufficient, so normality holds
# * 4) Remember: **A Z-test can only be used if the population standard deviation is known and the sample size is 30 data points or larger.** So we can apply single sample Z-test here.
# * 5) Our test statistic will be to calculate value of `Z`
#
# Here normality assumptions are valid as n >=30, then we can convert it into standard normal variate.(A standard normal random variable is a normally distributed random variable with mean μ=0 and standard deviation σ=1. It will always be denoted by the letter Z)
#
#     Z = (x̄ - μ) / (σ/sqrt(n)) = (53-50) / (5/sqrt(30)) = 3.28
#
# * As we have converted into standard normal variate, it will be a bell curve and look like below diagram. Now as our alternate assumption is μ > 50(which means we need to look at right side of graph), and our significance level α is 0.05, then we need to find such value of Z in x-axis, for which area on right side is 0.05 and remaining on left is 0.95.
# * We will use z-table(https://www.z-table.com/) to find this value of Z. We get 1.65 from table
#
# ![Z-test-figure](images/ztest1.png)
#
#
# * Now we have got 3.28 as Z-statistic, which will lie on right side of 1.65. Now if our data is falling in this shaded area (which is here also called rejection region) then we will reject null hypothesis, where left area is no rejection region which means if our Z value was in left side(unshaded part), then we cannot reject null hypothesis.
# * Since here it is 3.28 and it is falling in rejection region, so we can say we have strong evidence against null hypothesis and in favour of alternal hypothesis. So we can reject the null hypothesis therefore we can say training program can be beneficial and our daily average output will be greater than 50.
#
# ![Z-test-figure2](images/ztest2.png)
#
#
# **Let's take another example of Z-test**:
#
# Example 2:
# Suppose a snack food company claims that their Lays wafer packets contain an
# average weight of 50 grams per packet. To verify this claim, a consumer watchdog
# organization decides to test a random sample of Lays wafer packets. The
# organization wants to determine whether the actual average weight differs
# significantly from the claimed 50 grams. The organization collects a random
# sample of 40 Lays wafer packets and measures their weights. They find that the
# sample has an average weight of 49 grams, with a known population standard
# deviation of 4 grams.
#
# Answer:
#
# μ(avg wt. given) = 50
#
# n(sample) = 50
#
# x̄(sample mean) = 49
#
# σ(std dev) = 4
#
# Now we need to do hypothesis and proof that weight is less than 50 ore greater than 50, performing steps of hypothesis testing.
# * 1) H₀(null hypothesis) weight remains 50; Hₐ(alternate hypothesis) μ ≠ 50
# * 2) α (significance level) = Let's take it as 0.05
# * 3) Here sample size is =40, so according to central limit theorem, sample sizes equal to or greater than 30 are often considered sufficient, so normality holds.
# * 4) Remember: **A Z-test can only be used if the population standard deviation is known and the sample size is 30 data points or larger.** So we can apply single sample Z-test here.
# * 5) Our test statistic will be to calculate value of `Z`
# * 6) Conduct test: We will calculate value of Z
#
#         Z = (x̄ - μ) / (σ/sqrt(n)) = (49-50) / (4/sqrt(40)) = -1.58
#
#
# * Now our alternate hypothesis is μ ≠ 50, hence we need to apply two tailed test, we need to divide equal area of α (significance level) on the both side of graph, which will become 0.025
#
# ![Z-test-figure3](images/ztest3.png)
#
# * Now we see that we get -1.96 and 1.96 as value of Z from Z-table, and Z-statistic we got was -1.58, **which lies in non shaded area which is non rejection area. Hence we cannot reject the null hypothesis here**. Hence we cannot prove that chips weight is more or less than 50.
#
#
# ### Significance Level:
# * It is denoted as α (alpha)
# * **It is a predetermined threshold used in hypothesis testing to determine whether the null hypothesis should be rejected or not. It represents the probability of rejecting the null hypothesis when it is actually true**, also known as Type 1 error.
# * When we keep increasing α the non rejection region will keep shriking hence accepting null hypothesis probability is getting reduce, on the other hand if we decrease α then rejection region will keep shriking and hence increasing probability of accepting null hypothesis.
#
# ![Significancelevel](images/significancelevel.png)
#
# * In above image, in white area null hypothesis is correct and in red area alternate hypothesis is correct.
#
#
# ### Problem with Rejection Region Approach:
# * Let's say if we got Z-statistic value as 1.96 and our critical value(obtained from Z-table) was 1.95, in this case, as our value is falling in rejection region, so just because of 0.01(a very small number) only we need to reject null hypothesis. Here critical point becomes very important in rejection region approach.
# * Let's say if Z value is 15 and Z-statistic value is 2, here we can see difference between 2 points is a lot, both are in rejection region but still not able to differentiate between these two numbers, hence we are **not able to tell strength of evidence here** as when value is 15 we have strong reason to reject but not in case of 2.
#
#
# * Hence people usually don't use rejection region approach, they use p-value approach, where we calculate p-value. Where p-value is number from which we can measure strength of evidence to reject or accept.
#
#
#
#
# ### Type 1 vs Type 2 Error:
#
#
# In hypothesis testing, there are two types of errors that can
# occur when making a decision about the null hypothesis: Type
# I error and Type II error.
#
# ![H0-H1.png](attachment:H0-H1.png)
#
#
# - **Type-I (False Positive) error** occurs when the sample results, lead to the **rejection of the null hypothesis when it is in fact true**.
# - In other words, it's the mistake of finding a significant effect or relationship when there is none. The probability of committing a Type I error is denoted by α (alpha), which is also known as the significance level. By choosing a significance level, researchers can control the risk of making a Type I error.
#
#
# - **Type-II (False Negative) error** occurs when based on the sample results, **the null hypothesis is not rejected when it is in fact false**.
# - This means that the researcher fails to detect a significant effect or relationship when one actually exists. The probability of committing a Type II error is denoted by β (beta).

# %% [markdown]
# ### One sided vs two sided test:
#
# **One-sided (one-tailed) test**:
#
# * A one-sided test is used when the researcher is interested in testing the effect in a specific direction (either greater than or less than the value specified in the null hypothesis). The alternative hypothesis in a one-sided test contains an inequality (either ">" or "<").
# * One-sided test can be right tailed test or left tailed test.
# * Example: A researcher wants to test whether a new medication increases the average recovery rate compared to the existing medication.
# * Example: Shooting a YouTube video in a new way will increase average view duration then we will do right tailed test, or if our hypothesis is shooting a YouTube video in a new way will decrease average view duration then we will do left tailed test.
#
#
# **Two-sided (two-tailed) test**:
# * A two-sided test is used when the researcher is interested in testing the effect in both directions (i.e., whether the value specified in the null hypothesis is different, either greater or lesser). The alternative hypothesis in a two-sided test contains a "not equal to" sign (≠).
# * Example: A researcher wants to test whether a new medication has a different average recovery rate compared to the existing medication.
#
#
#
#
#
# ![onetailedvstwotailed.png](attachment:onetailedvstwotailed.png)
#
#
# ### Advantages and Disadvantages:
# **Two-tailed test (two-sided)**:
#
# * Advantages:
#
# 1. **Detects effects in both directions**: Two-tailed tests can detect effects in both directions, which makes them suitable for situations where the direction of the effect is uncertain or when researchers want to test for any difference between the groups or variables..
#
# 2. **More conservative**: Two-tailed tests are more conservative because the significance level (α) is split between both tails of the distribution. This reduces the risk of Type I errors in cases where the direction of the effect is uncertain.
#
#
#
# * Disadvantages:
# 1. **Less powerful**: Two-tailed tests are generally less powerful than one-tailed tests because the significance level (α) is divided between both tails of the distribution. This means the test requires a larger effect size to reject the null hypothesis, which could lead to a higher risk of Type II errors (failing to reject the null hypothesis when it is false).
#
# 2. **Not appropriate for directional hypotheses**: Two-tailed tests are not ideal for cases where the research question or hypothesis is directional, as they test for differences in both directions, which may not be of interest or relevance.
#
#
#
# **One-tailed test (one-sided)**:
# * Advantages:
# 1. **More powerful**: One-tailed tests are generally more powerful than two-tailed tests, as the entire significance level (α) is allocated to one tail of the distribution. This means that the test is more likely to detect an effect in the specified direction, assuming the effect exists.
#
# 2. **Directional hypothesis**: One-tailed tests are appropriate when there is a strong theoretical or practical reason to test for an effect in a specific direction.
#
# * Disadvantages:
# 1. **Missed effects**: One-tailed tests can miss effects in the opposite direction of the specified alternative hypothesis. If an effect exists in the opposite direction, the test will not be able to detect it, which could lead to incorrect conclusions.
#
# 2. **Increased risk of Type I error**: One-tailed tests can be more prone to Type I errors if the effect is actually in the opposite direction than the one specified in the alternative hypothesis.
#
# ### Hypothesis Testing ML Applications:
# 1. **Model comparison**: Hypothesis testing can be used to compare the performance of different machine learning models or algorithms on a given dataset. For example, you can use a paired t-test to compare the accuracy or error rate of two models on multiple cross- validation folds to determine if one model performs significantly better than the other.
#
# 2. **Feature selection**: Hypothesis testing can help identify which features are significantly related to the target variable or contribute meaningfully to the model's performance. For example, you can use a t-test, chi-square test, or ANOVA to test the relationship between individual features and the target variable. Features with significant relationships can be selected for building the model, while non-significant features may be excluded.
#
# 3. **Hyperparameter tuning**: Hypothesis testing can be used to evaluate the performance of a model trained with different hyperparameter settings. By comparing the performance of models with different hyperparameters, you can determine if one set of hyperparameters leads to significantly better performance.
#
# 4. **Assessing model assumptions**: In some cases, machine learning models rely on certain statistical assumptions, such as linearity or normality of residuals in linear regression. Hypothesis testing can help assess whether these assumptions are met, allowing you to determine if the model is appropriate for the data.

# %% [markdown]
# ### How to set significance level?
# We know p + q = 1
#
#     // p = prob of wrong decision and q = prob of right decision
# Here p-value is only significance value(prob of wrong decision).
# So if let's say prob of being wrong decision is 0.1(out of 1), if we convert this to percentage we get 10%(which is our significance level), hence we can say this with 90% confidence that particular thing holds true.
#
# Some eg below:
#
# | p | Significance level | Confidence level |
# | :- | -: | :-: |
# | 0.1 | 10% | 90%
# | 0.05 | 5% | 95%
# | 0.01 | 1% | 99%
# | 0.001 | 0.1% | 99.9%
#
# Let's learn by solving a question:
#
# **Ques**: The mean lifetime of a sample of 81 glucometer produced by company is found to be 58 months with standard deviation(σ) of 10 months. Company claims that mean lifetime of the glucometer is 60 months. Test the hypothesis at 5% level of significance, whether the 58 months lifetime is acceptable or not?
#
# **Ans**:
# Null hypothesis: There is no significant difference between lifetime of sample and populations
# Alternate hypothesis: There is significant difference between lifetime of sample and populations
#
# *(In this case mean lifetime was given 60 months but it came to be 58 months for a sample. Now after hypothesis testing if we see that there is 5% significant level difference between both(sample and population), then we can say that both are equal by 95% confidence. But remember we decide this after doing hypothesis test only.)*
#
# First we will calculate standard error of mean(SEM) = σ/√n = 10/√81 = 1.11
#
# // Standard deviation is divided by √n: https://math.stackexchange.com/questions/504288/what-situation-calls-for-dividing-the-standard-deviation-by-sqrt-n
#
# And then we calculate Z-score: z = (x-μ)/σ = |x-μ|/ SEM = |58-60|/1.11 = 1.80
#
# Let's consider this normal distribution graph, all values lies in this graph, when significance level is 5%(p-value is 0.05) so there is 5% chance of being wrong, which is shown on the ends. And 95% chance is there that it will be right.
#
# ![signif_level_graph.png](attachment:signif_level_graph.png)
