# %% [markdown]
# ## What is Normal distribution:
# * Normal distribution, also known as Gaussian distribution, is a probability distribution that is commonly used in statistical analysis. It is a continuous probability distribution(i.e PDF) that is symmetrical around the mean, with a bell-shaped curve.
# * It is also called Gaussian distribution because it was first discovered by Carl Friedrich Gauss.
#
# ![normal_distribution.png](attachment:normal_distribution.png)
#
# * Few important properties of normal(gaussian) distribution:
#     * It has bell shaped curve.
#     * End points are called tails and line at tails are **asymptotic** (An asymptotic line is a line that gets closer and closer to a curve as the distance gets closer to infinity). In simple language, if we see lines at tail doesn't touch x-axis, it is considered that they touch the x-axis at infinity.
#     * The normal distribution is a probability distribution. It is also called Gaussian distribution because it was first discovered by Carl Friedrich Gauss.
#     * In normal distribution, **most of the points lie around center i.e. mean and less point lie away from center**.
#
#
#
# * The normal distribution is characterized by two parameters: the mean (μ) and the standard deviation (σ). The mean represents the centre of the distribution, while the standard deviation represents the spread of the distribution.
#
# **Why is it so important?**
# It is very common in real world(that's why named normal too): Many natural phenomena follow a normal distribution, such as the heights of people, the weights of objects, the IQ scores of a population, and many more. Thus, the normal distribution provides a convenient way to model and analyse such data.
#
# * We also have a equation of PDF of normal distribution, no need to memorized it (Just google it see)
#
# **Note**: Check this app, to observe effects of increase or decreasing μ and σ, in case of a normal distribution: https://samp-suman-normal-dist-visualize-app-lkntug.streamlit.app/

# %% [markdown]
# ## Standard Normal Variate(Z) or Standard Normal Distribution:
# * It is a special case of normal distribution.
# * A Standard Normal Variate(Z) is a standardized form of the normal distribution with mean = 0 and standard deviation = 1.
# * Here in below graph we can see middle point will be always 0, where in normal distribution, it can be 0 or any other value too.
# * Also here each step of standard deviation is of 1 unit, which means on x-axis we mark 1, 2, 3 and on negative side -1, -2 and -3.
#
# ![standard_normal_variate.png](attachment:standard_normal_variate.png)
#
# * Benefits of Standard normal distribution:
#     * If we have let's say two normal distribution then we can standardize it and then we can compare those two different distribution.
#     * We can calculate all points probabilities, because for standard normal variate we have probability values.
#
# * How we can convert a normal distribution to standard normal distribution, we simply use Z-score here: Z = (x-μ)/σ, let's say if we have age column with some values which is normally distributed then we calculate Z-score value. Whatver values it generates, it directly creates standard normal values for it. If we plot these Z-values then it displays standard normal distribution.
#
# * **Let's understand with help of example**: Suppose the heights of adult males in a certain population follow a normal distribution with a mean of 68 inches and a standard deviation of 3 inches. What is the probability that a randomly selected adult male from this population is taller than 72 inches?
#     * First step is to calculate Z-value of 72:
#
#             (72-68)/3 = 1.33
#     * Now we look at Z-table to find 1.33 (In Z-table: For standard normal variate, for every x-value probability density is already calculated and stored in a table called Z-table)
#     * Basically Z-table value will give what probability of data before that point 1.33(i.e. LHS of 1.33 on graph).
#     * A z-table tells you the area underneath a normal distribution curve, to the left of the z-score.
#     * Let's say we got 0.90824, which means in whole data having <= prob of value being less than 1.33 is 90.8%
#     * Now in the queston we want bein taller than 72 inches(1.33 acc to standard normal distribution). So, 100-90.8 = 9.2%
#
#
#
#
# * Note: Sometimes when converted to standard normal distribution, mean value can come here close to zero not exactly zero, but very small number close to it. We still assume it correct.
#
#
# * CDF of normal distribution looks like S-shaped curve

# %% [markdown]
# ### Properties of Normal Distribution:
# 1. **Symmetricity**: The normal distribution is symmetric about its mean, which means that the probability of observing a value above the mean is the same as the probability of observing a value before the mean. The bell-shaped curve of the normal distribution reflects this symmetry.
#
# 2. Measures of Central Tendencies are equal: **In normal distribution, mean=median=mode**
#
# 3. **Empirical Rule**: The normal distribution has a well-known empirical rule, also called the 68-95-99.7 rule, which states that approximately 68% of the data falls within one standard deviation of the mean, about 95% of the data falls within two standard deviations of the mean, and about 99.7% of the data falls within three standard deviations of the mean.
#
# ![empirical_rule.png](attachment:empirical_rule.png)
#
# 4. Area under normal distribution curve is 1
#
# ### Uses of Normal Distribution in Data Science:
# * Outlier detection: If any point is outside of -3 or +3 std deviation then we treat it as outlier.
# * Assumptions on data for ML algorithms -> Linear Regression assumes residual error is normally distributed, Logistic Regression take assumption that data is normally distributed. It gives good result if data is normally distributed.
# * Hypothesis Testing: Many tests here assumes that data is normally distributed.
# * Central Limit Theorem

# %% [markdown]
# ## Skewness:
#
#
# - In probability theory and statistics, skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean. The skewness value can be positive, zero, negative, or undefined.
#
# - In simple words, skewness indicates that data is not symmetrical, which means it is not normally distributed.
#
# - If we have some data and if we plot it on any histogram or any other similar graph and then if we see a elongated line i.e. if one tail is longer than another, the distribution is skewed. These distributions are sometimes called asymmetric or asymmetrical distributions as they don’t show any kind of symmetry.
#
#
# ### Normal Distribution:
#
# - The normal distribution is a symmetric distribution with no skew. The tails are exactly the same.
#
# ![Symmetrical Distribution](images/sym_dist.png)
#
# - Most of the machine learning algorithms likes the data to have this kind of distribution.
#
# - Here mean = median = mode (approximately equal)
#
# - Examples of normal distribution:
# 	-- weight distribution
# 	-- height distribution
# 	-- age distribution
#
#
# ### Left-skewed Distribution (Negatively skewed)
#
# - A left-skewed distribution has a long left tail. Left-skewed distributions are also called negatively-skewed distributions. That’s because there is a long tail in the negative direction on the number line. The mean is also to the left of the peak.
#
# ![Left Skewed](images/left_skewed.jpeg)
#
# - Here mode > median > mean
#
# - Remember: In positive or negative skewed mean will be always on skewed side as mean is impacted by outliers and on skewed side outliers are there.
#
# - Examples of left-skewed distribution:
# 	-- life span of human
# 	-- age of retirement
#
#
# ### Right-skewed Distribution (Positively skewed):
#
# - A right-skewed distribution has a long right tail. Right-skewed distributions are also called positive-skew distributions. That’s because there is a long tail in the positive direction on the number line. The mean is also to the right of the peak.
#
# ![Right Skewed](images/right_skewed.jpeg)
#
#
# - Examples of right-skewed distribution:
# 	-- wealth distribution in world
# 	-- salary in a company
#
# - Here mean > median > mode
#
# ## Statistical Moments:
# * In Statistics, Moments are popularly used to describe the characteristic of a distribution. Let’s say the random variable of our interest is X then, moments are defined as the X’s expected values.
# * For Example, E(X), E(X²), E(X³), E(X⁴),…, etc.
# * The four commonly used moments in statistics are- the mean, variance, skewness, and kurtosis.
#
# ### Kurtosis:
# * It is the 4th statistical moment.
# * In probability theory and statistics, kurtosis (meaning "curved, arching") is a measure of the "tailedness" of the probability distribution of a real-valued random variable.
# * In simple language it measures the amount in the tails and outliers.
# * Like skewness, kurtosis describes a particular aspect of a probability distribution.
#
# * **Practical Use-case**:
#     * In finance, kurtosis risk refers to the risk associated with the possibility of extreme outcomes or "fat tails" in the distribution of returns of a particular asset or portfolio.
#     * If a distribution has high kurtosis, it means that there is a higher likelihood of extreme events occurring, either positive or negative, compared to a normal distribution.
#     * In finance, kurtosis risk is important to consider because it indicates that there is a greater probability of large losses or gains occurring, which can have significant implications for investors. As a result, investors may want to adjust their investment strategies to account for kurtosis risk.
#
# * Excess Kurtosis:
#     * Excess kurtosis is a measure of how much more peaked or flat a distribution is compared to a normal distribution, which is considered to have a kurtosis.
#
#
# ## How to find if a given distribution is normal or not?
#
# If we need to find whether a feature in dataset in normally distributed or not, we can:
#
# * **Visual inspection**: One of the easiest ways to check for normality is to visually inspect a histogram or a density plot of the data. A normal distribution has a bell-shaped curve, which means that the majority of the data falls in the middle, and the tails taper off symmetrically. If the distribution looks approximately bell-shaped, it is likely to be normal.
#
#
# * **QQ Plot**: Another way to check for normality is to create a normal probability plot (also known as a Q-Q plot) of the data. A normal probability plot plots the observed data against the expected values of a normal distribution. If the data points fall along a straight line, the distribution is likely to be normal.
#
#
# * **Statistical tests**: There are several statistical tests that can be used to test for normality, such as the Shapiro-Wilk test, the Anderson-Darling test, and the Kolmogorov-Smirnov test. These tests compare the observed data to the expected values of a normal distribution and provide a p-value that indicates whether the data is likely to be normal or not. A p-value less than the significance level (usually 0.05) suggests that the data is not normal.
#
#
#
# **What is a QQ Plot and how is it plotted?**
#
# * A QQ plot (quantile-quantile plot) is a graphical tool used to assess the similarity of the distribution of two sets of data. It is particularly useful for determining whether a set of data follows a normal distribution.
#
# * On a high level, here we take two set of distributions, then we compare their similarity. Let'say we use X and Y, where is data or particular feature of the column and Y is theoritical distributions(theoritical distributions means we already know type of data, like if already know it is normal distribution) Then we compare both them, and QQ plot will tell just that whether both of them are comparable or not. If comparable then X is normally distributed else not normally distributed.
#     * In detailed level, we first take some theoritical data which is let' say normally distributed. We sort it and calculate quantiles of the data.
#     * Then our own column data is sorted and we calculate quantiles of the data.
#     * Then we plot each point from X and Y from different quantiles and plot a scatter point graph, like below.
#     * Now if after plotting all the points, if in graph we can see they are in single line. Then we can say that X and Y have same distribution else not.
#
# ![qq_plot.png](attachment:qq_plot.png)
#
# * In python use:
#         import statsmodel.api as sm
#         fig = sm.qqplot(df['sepal_length'], line=55, fit=True)
#
# * How to interpret different QQplot: See images from here: https://drive.google.com/file/d/1sd4nz8PNsGc334ng86V8uKvJNqhWyRZ2/view
#
# * Ques: Does QQ plot only detect normal distribution?
#     * Ans: No, it can be any distribution
